# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
fb = pd.read_csv('data/facebook.csv',index_col = 'Date')
ms = pd.read_csv('data/microsoft.csv',index_col = 'Date')

# %%
# %matplotlib inline
fb.loc['2015-01-01':'2015-12-31','Close'].plot()
fb.loc['2016-01-01':'2016-12-31','Close'].plot()
fb.loc['2017-01-01':'2017-12-31','Close'].plot()
fb.loc['2018-01-01':'2018-12-31','Close'].plot()
fb.loc['2019-01-01':'2019-12-31','Close'].plot()

# %%
fb.loc[:,'Close'].plot(figsize=(8,5))

# %%
fb.shape
# Out:
# (1335, 6)

# %%
fb.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1335.000000  1335.000000  1335.000000  1335.000000  1335.000000
# mean    145.712292   147.215386   144.133633   145.762682   145.762682
# std      39.069390    39.437469    38.703055    39.107562    39.107562
# min      74.040001    74.830002    72.000000    74.050003    74.050003
# 25%     113.905002   114.814999   112.970001   114.024997   114.024997
# 50%     150.300003   151.990005   148.860001   150.289993   150.289993
# 75%     178.834999   180.364998   177.214996   178.894996   178.894996
# max     222.570007   224.199997   221.279999   223.229996   223.229996
#
#              Volume
# count  1.335000e+03
# mean   2.254938e+07
# std    1.376132e+07
# min    5.913100e+06
# 25%    1.429125e+07
# 50%    1.908880e+07
# 75%    2.561425e+07
# max    1.698037e+08

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  79.540001  79.800003  77.860001  78.019997  78.019997  19935400
# 2015-01-02  78.580002  78.930000  77.699997  78.449997  78.449997  18177500
# 2015-01-05  77.980003  79.250000  76.860001  77.190002  77.190002  26452200
# 2015-01-06  77.230003  77.589996  75.360001  76.150002  76.150002  27399300
# 2015-01-07  76.760002  77.360001  75.820000  76.150002  76.150002  22045300
